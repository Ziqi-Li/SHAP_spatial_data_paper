# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

# %%
chicago = gpd.read_file("chicago_tnp.geojson")

# %%
chicago['pct_white'] = 1-chicago['pct_nonwhite']
# centroids
chicago['x_coord'] = chicago.geometry.centroid.x
chicago['y_coord'] = chicago.geometry.centroid.y
# log transformation
chicago['Trips_log'] = np.log(chicago['TripCount'])
chicago['PD_log'] = np.log(chicago['population_den'])
# Out:
# /Users/ziqi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/ziqi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   after removing the cwd from sys.path.

# %%
fig, ax = plt.subplots(dpi=300)

chicago.plot(ax=ax,column='Trips_log',legend=True,figsize=(15,8),cmap='viridis')
plt.title("Map of The Dependent Variable: \nLog (Trip Demand) ",fontsize=8)

ax.axis('off')
# Out:
# (1090883.0228337517, 1210722.3614912496, 1806999.300562503, 1958619.5146374977)

# %%
X_vars = ['pct_18to34','pct_white','pct_bachelorORhigher',
          'pct_no_vehicle','PD_log','job_entropy','network_den',
          'TripMiles_mean','pct_share']

X = chicago[X_vars]
X_coords = chicago[X_vars + ['x_coord','y_coord']]

coords = chicago[['x_coord','y_coord']].values

y = chicago['Trips_log']

# %%
corr = X_coords.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_9ee06e0e_eb2a_11ec_a890_acde48001122row0_col0,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row1_col1,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row2_col2,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row3_col3,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row4_col4,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row5_col5,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row6_col6,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row7_col7,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row8_col8,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row9_col9,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row10_col10{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row0_col1{
#             background-color:  #f7b89c;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row0_col2{
#             background-color:  #ef886b;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row0_col3,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row0_col6,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row6_col5{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row0_col4{
#             background-color:  #f6bda2;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row0_col5{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row0_col7{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row0_col8{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row0_col9,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row8_col9,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row9_col0{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row0_col10,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row3_col8{
#             background-color:  #efcfbf;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row1_col0{
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row1_col2,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row2_col1{
#             background-color:  #ee8669;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row1_col3,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row1_col8,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row2_col8,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row7_col0,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row7_col6,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row8_col1,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row8_col2,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row8_col4,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row8_col5,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row8_col10,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row10_col7,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row10_col9{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row1_col4{
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row1_col5{
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row1_col6,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row5_col6{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row1_col7{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row1_col9,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row10_col8{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row1_col10,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row5_col1{
#             background-color:  #f49a7b;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row2_col0{
#             background-color:  #f4987a;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row2_col3,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row9_col1{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row2_col4{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row2_col5{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row2_col6,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row6_col0{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row2_col7,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row7_col10{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row2_col9{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row2_col10{
#             background-color:  #f7b599;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row3_col0{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row3_col1,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row3_col7{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row3_col2{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row3_col4,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row4_col5{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row3_col5{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row3_col6,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row6_col8,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row7_col1{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row3_col9,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row5_col10,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row8_col7{
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row3_col10{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row4_col0{
#             background-color:  #f7b99e;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row4_col1{
#             background-color:  #f7bca1;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row4_col2{
#             background-color:  #f7af91;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row4_col3,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row4_col6{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row4_col7,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row9_col10{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row4_col8{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row4_col9{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row4_col10{
#             background-color:  #f7b497;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row5_col0{
#             background-color:  #dcdddd;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row5_col2,#T_9ee06e0e_eb2a_11ec_a890_acde48001122row7_col8{
#             background-color:  #f7b396;
#             color:  #000000;
#         }#T_9ee06e0e_eb2a_11ec_a890_acde48001122row5_col3{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_9ee06e0e_eb

# %%
import spreg
from libpysal.weights import Queen

w = Queen.from_dataframe(chicago)
w.transform = 'R'

slm = spreg.ML_Lag(y.values, X.values, w=w, name_y='y', name_x=X_vars)

print(slm.summary)
# Out:
# /Users/ziqi/opt/anaconda3/lib/python3.7/site-packages/libpysal/weights/weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#  There is 1 island with id: 167.
#   warnings.warn(message)
# /Users/ziqi/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py:770: RuntimeWarning: Method 'bounded' does not support relative tolerance in x; defaulting to absolute tolerance.
#   "defaulting to absolute tolerance.", RuntimeWarning)
# /Users/ziqi/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ('WARNING: ', 167, ' is an island (no neighbors)')
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: MAXIMUM LIKELIHOOD SPATIAL LAG (METHOD = FULL)
# -----------------------------------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :           y                Number of Observations:         795
# Mean dependent var  :      9.7680                Number of Variables   :          11
# S.D. dependent var  :      1.8456                Degrees of Freedom    :         784
# Pseudo R-squared    :      0.7582
# Spatial Pseudo R-squared:  0.7311
# Sigma-square ML     :       0.823                Log likelihood        :   -1059.526
# S.E of regression   :       0.907                Akaike info criterion :    2141.051
#                                                  Schwarz criterion     :    2192.513
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       6.0902954       0.6570751       9.2687958       0.0000000
#           pct_18to34       1.8845447       0.4104121       4.5918354       0.0000044
#            pct_white      -0.8560436       0.2095859      -4.0844528       0.0000442
# pct_bachelorORhigher       1.5505535       0.2738776       5.6614841       0.0000000
#       pct_no_vehicle       0.4005986       0.2796058       1.4327260       0.1519361
#               PD_log       0.2179340       0.0636978       3.4213710       0.0006231
#          job_entropy       0.6594255       0.2199372       2.9982445       0.0027154
#          network_den       0.0051303       0.0054753       0.9369917       0.3487628
#       TripMiles_mean      -0.2262009       0.0310774      -7.2786231       0.0000000
#            pct_share      -2.0028625       0.6949948      -2.8818382       0.0039536
#                  W_y       0.3620287       0.0434754       8.3272060       0.0000000
# ------------------------------------------------------------------------------------
# ================================ END OF REPORT =====================================

# %%
plt.hist(0.36*w.full()[0].dot(y.values))
# Out:
# (array([  1.,   0.,   0.,   3.,  18., 152., 296., 176., 119.,  30.]),
#  array([0.        , 0.51399608, 1.02799215, 1.54198823, 2.05598431,
#         2.56998038, 3.08397646, 3.59797254, 4.11196862, 4.62596469,
#         5.13996077]),
#  <BarContainer object of 10 artists>)

# %%
from mgwr.gwr import GWR,MGWR                                                   
from mgwr.sel_bw import Sel_BW

# %%
#Data Mean centering
y_std = y
X_std = (X - X.mean(axis=0))

# %%
# %%time
sel = Sel_BW(coords,y_std.values.reshape(-1,1),X_std.values,multi=True)
bws = sel.search(verbose=False)
result = MGWR(coords,y_std.values.reshape(-1,1),X_std.values,selector=sel).fit()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Backfitting', max=200.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Inference', max=1.0, style=ProgressStyle(description_widt…
# CPU times: user 27min 37s, sys: 22.6 s, total: 27min 59s
# Wall time: 17min 57s

# %%
result.summary()
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                 795
# Number of covariates:                                                    10
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                            732.799
# Log-likelihood:                                                   -1095.671
# AIC:                                                               2211.343
# AICc:                                                              2213.680
# BIC:                                                              -4509.700
# R2:                                                                   0.729
# Adj. R2:                                                              0.726
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                   9.768      0.034    285.056      0.000
# X1                                   2.384      0.436      5.473      0.000
# X2                                  -1.127      0.222     -5.077      0.000
# X3                                   2.478      0.262      9.448      0.000
# X4                                   0.667      0.294      2.267      0.023
# X5                                   0.359      0.067      5.374      0.000
# X6                                   0.921      0.234      3.931      0.000
# X7                                   0.006      0.006      0.992      0.321
# X8                                  -0.370      0.027    -13.575      0.000
# X9                                  -2.660      0.735     -3.618      0.000
#
# Multi-Scale Geographically Weighted Regression (MGWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive bisquare
# Criterion for optimal bandwidth:                                       AICc
# Score of Change (SOC) type:                                     Smoothing f
# Termination criterion for MGWR:                                       1e-05
#
# MGWR bandwidths
# ---------------------------------------------------------------------------
# Variable             Bandwidth      ENP_j   Adj t-val(95%)   Adj alpha(95%)
# X0                     793.000      1.107            2.006            0.045
# X1                     793.000      1.184            2.034            0.042
# X2                     591.000      1.623            2.163            0.031
# X3                     793.000      1.096            2.002            0.046
# X4                     793.000      1.277            2.066            0.039
# X5                      52.000     36.509            3.212            0.001
# X6                     328.000      4.729            2.563            0.011
# X7                     467.000      2.971            2.395            0.017
# X8                     527.000      2.606            2.347            0.019
# X9                      44.000     41.154            3.247            0.001
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                            446.031
# Effective number of parameters (trace(S)):                           94.256
# Degree of freedom (n - trace(S)):                                   700.744
# Sigma estimate:                                                       0.798
# Log-likelihood:                                                    -898.320
# AIC:                                                               1987.151
# AICc:                                                              2013.395
# BIC:                                                               2432.792
# R2                                                                    0.835
# Adjusted R2                                                           0.813
#
# Summary Statistics For MGWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                       10.048      0.008     10.033     10.051     10.060
# X1                        1.539      0.037      1.478      1.533      1.656
# X2                       -0.230      0.238     -0.628     -0.091      0.028
# X3                        2.706      0.018      2.672      2.712      2.736
# X4                        1.371      0.065      1.294      1.379      1.476
# X5                        0.198      0.453     -1.153      0.159      1.459
# X6                        0.441      0.539     -0.675      0.386      1.439
# X7                       -0.002      0.007     -0.019     -0.001      0.010
# X8                       -0.301      0.081     -0.423     -0.244     -0.219
# X9                       -2.357      3.865    -10.621     -2.552     15.173
# ===========================================================================

# %% [markdown]
# ### Machine Learning

# %%
import xgboost
import shap

from sklearn.metrics import mean_squared_error, r2_score

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_coords, y, 
                                                    test_size = 0.2,
                                                    random_state = 222)

# %% [markdown]
# ### Hyperparameter Tuning

# %%
# %%time
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials, space_eval

# Choose hyperparameter domain to search over
space = {
        'max_depth':hp.choice('max_depth', np.arange(1, 30, 1, dtype=int)),
        'colsample_bytree':hp.quniform('colsample_bytree', 0.3, 1.01, 0.05),
        'min_child_weight':hp.choice('min_child_weight', np.arange(1, 30, 1, dtype=int)),
        'subsample':        hp.quniform('subsample', 0.3, 1.01, 0.05),
        'learning_rate':    hp.choice('learning_rate',    np.arange(0.05, 1.01, 0.05)),
        'gamma': hp.quniform('gamma', 0.1, 5, 0.05),
    
        'objective':'reg:squarederror',
        'eval_metric': 'rmse',
    }

def score(params, n_folds=5):
    
    #Cross-validation
    d_train = xgboost.DMatrix(X_coords,y)
    
    cv_results = xgboost.cv(params, d_train, nfold = n_folds, num_boost_round=500,
                        early_stopping_rounds = 10, metrics = 'rmse', seed = 0)
    
    loss = min(cv_results['test-rmse-mean'])
    
    return loss


def optimize(trials, space):
    
    best = fmin(score, space, algo=tpe.suggest, max_evals=2000,
                rstate=np.random.RandomState(333))#Add seed to fmin function
    return best
# Out:
# CPU times: user 128 ms, sys: 54.5 ms, total: 182 ms
# Wall time: 262 ms

# %%
trials = Trials()
best_params = optimize(trials, space)

# Return the best parameters
best_params = space_eval(space, best_params)

best_params
# Out:
# 100%|██████████| 2000/2000 [13:50<00:00,  2.41trial/s, best loss: 0.8733162]
# {'colsample_bytree': 0.75,
#  'eval_metric': 'rmse',
#  'gamma': 0.15000000000000002,
#  'learning_rate': 0.05,
#  'max_depth': 18,
#  'min_child_weight': 3,
#  'objective': 'reg:squarederror',
#  'subsample': 0.75}

# %% [markdown]
# ### Fit xgboost model

# %%
data_test = xgboost.DMatrix(X_test,y_test)

data = xgboost.DMatrix(X_train,y_train)
final_model = xgboost.train(best_params, data, num_boost_round=500, verbose_eval=False,
                            evals=[(data_test, "Test")],early_stopping_rounds=10)


data_all = xgboost.DMatrix(X_coords)
y_pred = final_model.predict(data_all)
print(np.sqrt(mean_squared_error(y, y_pred)))
print(r2_score(y, y_pred))
# Out:
# 0.44647018017266515
# 0.9414024026575328

# %% [markdown]
# ## SHAP analysis of xgboost results

# %%
explainer_shap = shap.TreeExplainer(final_model)
shap_values = explainer_shap(X_coords)

# %%
shap_interaction_values = shap.TreeExplainer(
    final_model).shap_interaction_values(X_coords)

# %%
X_names = ['pct_18_34','pct_white','pct_bach',
          'pct_no_car','log_pop_den','job_entropy','network_den',
          'ave_trip_dist','pct_share','x_coord','y_coord']

fig, ax = plt.subplots(figsize=(8, 6),dpi=160)

shap.summary_plot(shap_interaction_values, X_coords, max_display=15, 
                  feature_names = X_names,
                  plot_type="compact_dot")

# %% [markdown]
# ## Compute Confidence intervals for SHAPs

# %% [markdown]
# ```
# Function to compute 95% confidence interval around SHAP estimates
#        Residual reampling-based boostrapping
#     Step:  Repeat N times:
#             1) Randomly resample residuals with replacement.
#             2) Model Y_pred + residuals ~ X
#             3) Compute SHAP values and save them
#     Get the 2.5 percentile and 97.5 percentile from the sampling distribution.
# ```

# %%
from tqdm import tqdm

shap_bootstrap_list = []

def boostrap_shap(y_pred):
    n = y.shape[0]
    err = y - y_pred
    
    for i in tqdm(range(5000)):
        
        random_sample_index = np.random.choice(np.arange(n), size=n, replace=True)
        
        y_sample = y_pred + err[random_sample_index]
        
        sample_data = xgboost.DMatrix(X_coords,y_sample)
        
        sample_model = xgboost.train(best_params, sample_data, num_boost_round=500,verbose_eval=False,
                            evals=[(data_test, "Test")],early_stopping_rounds=10)
    
        explainer_shap = shap.Explainer(sample_model)
        shap_values = explainer_shap(X_coords)

        shap_bootstrap_list.append(shap_values.values)
        
    return np.array(shap_bootstrap_list)

# %%
# %%time
np.random.seed(333)

shap_bootstrap_list = boostrap_shap(y_pred)
# Out:
# 100%|██████████| 5000/5000 [1:20:13<00:00,  1.04it/s]
# CPU times: user 5h 30min 13s, sys: 8min 7s, total: 5h 38min 20s
# Wall time: 1h 20min 13s

# %% [markdown]
# ### Compute the confidence intervals for the global shap values

# %%
l_shap_global = np.abs(shap_bootstrap_list).mean(axis=1).mean(axis=0) - \
                np.percentile(np.abs(shap_bootstrap_list).mean(axis=1),axis=0, q=2.5)
                
u_shap_global = np.percentile(np.abs(shap_bootstrap_list).mean(axis=1),axis=0, q=97.5) - \
                np.abs(shap_bootstrap_list).mean(axis=1).mean(axis=0)

df_mean_shap = pd.DataFrame(np.vstack([np.array(X_coords.columns), 
                        np.abs(shap_bootstrap_list).mean(axis=1).mean(axis=0),
                        l_shap_global, u_shap_global,
                        np.percentile(np.abs(shap_bootstrap_list).mean(axis=1),axis=0, q=2.5),
                        np.percentile(np.abs(shap_bootstrap_list).mean(axis=1),axis=0, q=97.5) 
                                      ]).T,
                            columns=['Feature','SHAP', 'SHAP_err_l',
                                     'SHAP_err_u','SHAP_l','SHAP_u'])

# %%
df_mean_shap = df_mean_shap.sort_values(by="SHAP",ascending=True)

df_mean_shap["SHAP"] = df_mean_shap["SHAP"].astype("float")
df_mean_shap["SHAP_err_u"] = df_mean_shap["SHAP_err_u"].astype("float")
df_mean_shap["SHAP_err_l"] = df_mean_shap["SHAP_err_l"].astype("float")

# %% [markdown]
# ## Global feature importance

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(8,6),dpi=160)

ax.barh(df_mean_shap.Feature, df_mean_shap.SHAP,
        xerr=df_mean_shap[['SHAP_err_l','SHAP_err_u']].values.T,color=shap.plots.colors.blue_rgb)

ax.set_xlabel('SHAP (average impact on the outcome)',fontsize=13)
ax.tick_params(labelsize=13)

# %% [markdown]
# ### Visualize the confidence intervals for the local shap values

# %%
#Compute the 95% confidence interval
l_95 = np.percentile(shap_bootstrap_list,axis=0,q=2.5)
u_95 = np.percentile(shap_bootstrap_list,axis=0,q=97.5)

# %%
import seaborn as sns

def plot(ax,term=0):
    
    order = np.argsort(X_coords.values[:,term])

    ax.fill_between(X_coords.values[:,term][order], l_95[:,term][order], 
                     u_95[:,term][order],color='lightblue',alpha=0.6)
    
    ax.scatter(X_coords.values[:,term][order], shap_bootstrap_list.mean(axis=0)[:,term][order],
                s=10,color='black')
    
    ax.axhline(0,color='r', linestyle='--',)
    ax.set_xlabel(X_names[term],fontsize=13)
    #ax.set_ylim(-2.5,2.5)
    ax.set_ylabel("SHAP value",fontsize=13)
    plt.tight_layout()

# %% [markdown]
# ## Partial Dependence Plots

# %%
fig, ax = plt.subplots(3,3,figsize=(12,8),dpi=300)
ax = ax.ravel()
index = 0
for j in [2, 7, 0, 8, 3, 5, 1, 4, 6 ]:
    plot(ax=ax[index],term=j)
    index += 1

# %% [markdown]
# ## Spatial patterns of SHAP values

# %%
fig, ax = plt.subplots(3,3,figsize=(15,15))

for j in range(len(X_vars)):
    ax = ax.ravel()
    chicago.plot(ax=ax[j],column = shap_values.values[:,j],legend=True,
             vmin=-0.8,vmax=0.8,cmap=shap.plots.colors.red_white_blue)
    
    ax[j].set_title("SHAP for\n" + X_vars[j],fontsize=10)
    
#fig.delaxes(ax[-1])

# %% [markdown]
# ### Location Effect Map

# %%
fig, ax = plt.subplots(dpi=300)

chicago.plot(ax=ax,column = shap_values.values[:,-1] + shap_values.values[:,-2],
             legend=True,vmin=-0.6,vmax=0.6,figsize=(15,8),
                cmap=shap.plots.colors.red_white_blue)


plt.title("Location Effect on Ride-hailing Trip Demand\n(SHAP values of geographic coordinates)\n",fontsize=8)

plt.axis('off')
# Out:
# (1090883.0228337517, 1210722.3614912496, 1806999.300562503, 1958619.5146374977)

# %% [markdown]
# ## Feature maps

# %%
fig, ax = plt.subplots(3,3,figsize=(15,15),dpi=160)

for j in [2, 7, 0, 8, 3, 5, 1, 4, 6 ]:
    ax = ax.ravel()
    
    chicago.plot(ax=ax[j],column = shap_values.data[:,j],legend=True)
    
    ax[j].set_title(X_names[j],fontsize=14)
    ax[j].axis('off')
    
fig.tight_layout()
